# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
#data.id.nunique()

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data['Unnamed: 32'].isnull().all()
# Out:
# True

# %%
data = data.drop(['Unnamed: 32'], axis = 1)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
data.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %%
(data["diagnosis"].value_counts())/data.shape[0]
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
labels = 'Benign','Malign'
plt.pie(data['diagnosis'].value_counts(),labels=labels,autopct='%1.1f%%',startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c2c971f198>,
# ...
#  [Text(-0.3228026293005679, -1.051569523387132, 'Benign'),
#   Text(0.32280272775561086, 1.0515694931641641, 'Malign')],
#  [Text(-0.17607416143667337, -0.5735833763929811, '62.7%'),
#   Text(0.1760742151394241, 0.5735833599077259, '37.3%')])

# %%
map_category ={'B':0,'M':1}

# %%
data['diagnosis'] = data['diagnosis'].map(map_category)

# %%
#drop id column
data.drop(['id'],axis=1,inplace=True)

# %%
X=data.iloc[:,1:]

# %%
y=data.iloc[:,0]

# %%
y.name
# Out:
# 'diagnosis'

# %%
X.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
X_train.shape[0]
# Out:
# 426

# %%
X_test.shape[0]
# Out:
# 143

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
std.fit(X_train)
X_train = std.transform(X_train)

# %%
X_train
# Out:
# array([[-0.49543903, -0.33295097, -0.52705942, ..., -0.28129625,
#          0.87075345, -0.82150694],
#        [-0.61539505, -0.09230916, -0.64387003, ..., -0.6727791 ,
#         -0.58956283, -0.23353646],
#        [-0.34758627, -0.44147571, -0.34016244, ..., -0.46605104,
#         -1.4578161 , -0.73735802],
#        ...,
#        [-0.61539505, -0.14893076, -0.54639359, ...,  0.60480929,
#          2.94376766,  2.99681727],
#        [-1.43890703, -1.10677953, -1.31734362, ..., -0.99071879,
#         -1.03559422,  1.29239967],
#        [-0.08535684, -0.3353102 , -0.13594527, ..., -0.80641243,
#         -0.88321339, -0.75826125]])

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
train_accuracy = clf.score(X_train, y_train)
print(train_accuracy)
# Out:
# 0.9859154929577465

# %%
print(clf.predict(X_test[:1]))
# Out:
# [1]

# %%
from sklearn import metrics
pred = clf.predict(X_test)
#prob = clf.predict_proba(X_test)
pred_accuracy = metrics.accuracy_score(y_test, pred) 
#print("proba : ",prob)
print(pred_accuracy)
# Out:
# 0.3776223776223776

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(pred, y_test)
cm
# Out:
# array([[ 0,  0],
#        [89, 54]], dtype=int64)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()
dtc = dtc.fit(X_train,y_train)

# %%
import pydotplus
from IPython.display import Image
dot_data = tree.export_graphviz(dtc, out_file=None)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# ### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)

# %%
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(X_test)
cn = confusion_matrix(y_test,y_pred)
cn
# Out:
# array([[ 0, 89],
#        [ 0, 54]], dtype=int64)

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.3776223776223776

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns

# %%
sns.countplot(x='diagnosis', data=data)
plt.show()

# %%
sns.pairplot(data, hue='diagnosis', vars=['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'])

# %%
sns.pairplot(data, hue='diagnosis', vars=['radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se'])

# %%
sns.pairplot(data, hue='diagnosis', vars=['radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst'])

# %%
B = data[data.diagnosis==0]
M = data[data.diagnosis==1]

# %%
plt.scatter(B['area_mean'],B['texture_mean'],color='b')
plt.scatter(M['area_mean'],M['texture_mean'],color='g')

# %%
sns.swarmplot(x = 'diagnosis', y = 'area_mean', data = data)
